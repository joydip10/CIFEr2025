# %%
import yfinance as yf
import datetime

# %%
ticker = "AAPL"
start_date = datetime.datetime(2020, 1, 1)
end_date = datetime.datetime(2020, 12, 31)
data = yf.download(ticker, start=start_date, end=end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2020-01-02  74.059998  75.150002  73.797501  75.087502  72.876129  135480400
# 2020-01-03  74.287498  75.144997  74.125000  74.357498  72.167610  146322800
# 2020-01-06  73.447502  74.989998  73.187500  74.949997  72.742668  118387200
# 2020-01-07  74.959999  75.224998  74.370003  74.597504  72.400536  108872000
# 2020-01-08  74.290001  76.110001  74.290001  75.797501  73.565193  132079200

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
feature='Open'
data[feature].plot()
plt.title(f'{ticker} {feature} Price')
# Out:
# Text(0.5, 1.0, 'AAPL Open Price')

# %%
feature='High'
data[feature].plot()
plt.title(f'{ticker} {feature} Price')
# Out:
# Text(0.5, 1.0, 'AAPL High Price')

# %%
feature='Low'
data[feature].plot()
plt.title(f'{ticker} {feature} Price')
# Out:
# Text(0.5, 1.0, 'AAPL Low Price')

# %%
feature='Close'
data[feature].plot()
plt.title(f'{ticker} {feature} Price')
# Out:
# Text(0.5, 1.0, 'AAPL Close Price')

# %%
feature='Adj Close'
data[feature].plot()
plt.title(f'{ticker} {feature} Price')
# Out:
# Text(0.5, 1.0, 'AAPL Adj Close Price')

# %%
feature='Volume'
data[feature].plot()
plt.title(f'{ticker} {feature} Price')
# Out:
# Text(0.5, 1.0, 'AAPL Volume Price')

# %% [markdown]
# # Encoding

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from sklearn.model_selection import train_test_split

# %%
def autoencoder(input_dim):
    
    input_layer = Input(shape=(input_dim,))

    # Encoder   
    encoded = Dense(3, activation='relu')(input_layer)
    encoded = Dense(2, activation='relu')(encoded)
    encoded = Dense(1, activation='relu')(encoded)

    # Decoder
    decoded = Dense(2, activation='relu')(encoded)
    decoded = Dense(3, activation='relu')(decoded)
    decoded = Dense(input_dim, activation='linear')(decoded)

    autoencoder = Model(inputs=input_layer, outputs=decoded)

    autoencoder.compile(optimizer='adam', loss='mse')

    return autoencoder

# %%
def training(autoencoder, data, epochs=100, batch_size=32):
    
    train_data, test_data = train_test_split(stock_data, test_size=0.2, random_state=42)
    
    # Normalize
    train_data_normalized = (train_data - np.mean(train_data, axis=0)) / np.std(train_data, axis=0)
    test_data_normalized = (test_data - np.mean(test_data, axis=0)) / np.std(test_data, axis=0)
    

    history = autoencoder.fit(train_data_normalized, train_data_normalized,
                          epochs=epochs,
                          batch_size=batch_size,
                          shuffle=True,
                          validation_data=(test_data_normalized, test_data_normalized))
    
    return history

# %%
autoencoder = autoencoder(input_dim=6)
# Out:
# WARNING:tensorflow:From C:\Users\joydi\anaconda3\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\joydi\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
train=data.loc['2020-01-01':'2020-08-31']

# %%
test=data.loc['2020-09-01':]

# %%
train.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-08-25  124.697502  125.180000  123.052498  124.824997  121.984589
# 2020-08-26  126.180000  126.992500  125.082497  126.522499  123.643448
# 2020-08-27  127.142502  127.485001  123.832497  125.010002  122.165390
# 2020-08-28  126.012497  126.442497  124.577499  124.807503  121.967491
# 2020-08-31  127.580002  131.000000  126.000000  129.039993  126.103691
#
#                Volume
# Date
# 2020-08-25  211495600
# 2020-08-26  163022400
# 2020-08-27  155552400
# 2020-08-28  187630000
# 2020-08-31  225702700

# %%
test.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-09-01  132.759995  134.800003  130.529999  134.179993  131.126709
# 2020-09-02  137.589996  137.979996  127.000000  131.399994  128.409973
# 2020-09-03  126.910004  128.839996  120.500000  120.879997  118.129349
# 2020-09-04  120.070000  123.699997  110.889999  120.959999  118.207542
# 2020-09-08  113.949997  118.989998  112.680000  112.820000  110.252762
#
#                Volume
# Date
# 2020-09-01  151948100
# 2020-09-02  200119000
# 2020-09-03  257599600
# 2020-09-04  332607200
# 2020-09-08  231366600

# %%
train.Close.plot()
plt.title(f'{ticker} Closing Price (Training Data)')
# Out:
# Text(0.5, 1.0, 'AAPL Closing Price (Training Data)')

# %%
test.Close.plot()
plt.title(f'{ticker} Closing Price (Testing Data)')
# Out:
# Text(0.5, 1.0, 'AAPL Closing Price (Testing Data)')

# %%
history = training(autoencoder, data, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# WARNING:tensorflow:From C:\Users\joydi\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 7/7 [==============================] - 1s 40ms/step - loss: 0.9246 - val_loss: 1.3536
# Epoch 2/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.9157 - val_loss: 1.3743
# Epoch 3/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.9083 - val_loss: 1.3937
# Epoch 4/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.9026 - val_loss: 1.4138
# Epoch 5/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.8968 - val_loss: 1.4325
# Epoch 6/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.8927 - val_loss: 1.4521
# Epoch 7/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.8884 - val_loss: 1.4704
# Epoch 8/100
# ...

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 6)]               0
#
#  dense (Dense)               (None, 3)                 21
#
#  dense_1 (Dense)             (None, 2)                 8
#
#  dense_2 (Dense)             (None, 1)                 3
#
#  dense_3 (Dense)             (None, 2)                 4
#
#  dense_4 (Dense)             (None, 3)                 9
#
#  dense_5 (Dense)             (None, 6)                 24
#
# ...
# Total params: 69 (276.00 Byte)
# Trainable params: 69 (276.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
